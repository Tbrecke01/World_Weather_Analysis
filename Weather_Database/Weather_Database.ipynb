# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

import time
from datetime import datetime

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Starting URL for Weather Map API Call.
url = "https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=" + weather_api_key
print(url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 767

# %%
# Create an empty list to hold the weather data.
city_data = []

# Create counters.
record_count = 1
set_count = 1

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    print(city_url)
        # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    #try
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_name = city_weather["name"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = ((city_weather["main"]["temp_max"]-273.15) * 9/5 + 32)
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city_name,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Description": city_description
                         })
    

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=porto novo
# Processing Record 1 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=tsihombe
# Processing Record 2 of Set 1 | east london
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=hilo
# Processing Record 3 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=verkh-usugli
# Processing Record 4 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=busselton
# Processing Record 5 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=albany
# Processing Record 6 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=carnarvon
# Processing Record 7 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=tuatapere
# Processing Record 8 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=goundam
# Processing Record 9 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=ribeira grande
# Processing Record 10 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=punta arenas
# Processing Record 11 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=tazovskiy
# Processing Record 12 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=barrow
# Processing Record 13 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=ahipara
# Processing Record 14 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=yellowknife
# Processing Record 15 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=louisbourg
# Processing Record 16 of Set 1 | east london
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=new norfolk
# Processing Record 17 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=portland
# Processing Record 18 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=kaitangata
# Processing Record 19 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=jamestown
# Processing Record 20 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=saint-philippe
# Processing Record 21 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=barentsburg
# Processing Record 22 of Set 1 | east london
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=bredasdorp
# Processing Record 23 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=kapit
# Processing Record 24 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=dikson
# Processing Record 25 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=vilyuysk
# Processing Record 26 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=ushuaia
# Processing Record 27 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=severo-kurilsk
# Processing Record 28 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=berlevag
# Processing Record 29 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=sobolevo
# Processing Record 30 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=soma
# Processing Record 31 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=bluff
# Processing Record 32 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=mataura
# Processing Record 33 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=hermanus
# Processing Record 34 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=koslan
# Processing Record 35 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=kruglolesskoye
# Processing Record 36 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=huambo
# Processing Record 37 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=huarmey
# Processing Record 38 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=namibe
# Processing Record 39 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=kiama
# Processing Record 40 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=kodiak
# Processing Record 41 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=garowe
# Processing Record 42 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=khatima
# Processing Record 43 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=taolanaro
# Processing Record 44 of Set 1 | east london
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=anuppur
# Processing Record 45 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=cape town
# Processing Record 46 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=horta
# Processing Record 47 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=mahebourg
# Processing Record 48 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=babu
# Processing Record 49 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=karratha
# Processing Record 50 of Set 1 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=baloda bazar
# Processing Record 1 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=belushya guba
# Processing Record 2 of Set 2 | east london
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=albion
# Processing Record 3 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=vaitupu
# Processing Record 4 of Set 2 | east london
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=khormuj
# Processing Record 5 of Set 2 | east london
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=punta alta
# Processing Record 6 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=ormara
# Processing Record 7 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=mys shmidta
# Processing Record 8 of Set 2 | east london
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=beringovskiy
# Processing Record 9 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=tuktoyaktuk
# Processing Record 10 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=leningradskiy
# Processing Record 11 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=flinders
# Processing Record 12 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=port hardy
# Processing Record 13 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=aiken
# Processing Record 14 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=rikitea
# Processing Record 15 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=husavik
# Processing Record 16 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=vardo
# Processing Record 17 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=broome
# Processing Record 18 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=narsaq
# Processing Record 19 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=atuona
# Processing Record 20 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=polewali
# Processing Record 21 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=terrace bay
# Processing Record 22 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=kankon
# Processing Record 23 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=tarakan
# Processing Record 24 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=tingrela
# Processing Record 25 of Set 2 | east london
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=deputatskiy
# Processing Record 26 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=lebu
# Processing Record 27 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=kotka
# Processing Record 28 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=alugan
# Processing Record 29 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=sitka
# Processing Record 30 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=jumla
# Processing Record 31 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=chuy
# Processing Record 32 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=san jose
# Processing Record 33 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=airai
# Processing Record 34 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=butaritari
# Processing Record 35 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=mendahara
# Processing Record 36 of Set 2 | east london
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=le vauclin
# Processing Record 37 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=port alfred
# Processing Record 38 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=castro
# Processing Record 39 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=olinda
# Processing Record 40 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=longyearbyen
# Processing Record 41 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=camacupa
# Processing Record 42 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=yarim
# Processing Record 43 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=mvuma
# Processing Record 44 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=rawson
# Processing Record 45 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=nanortalik
# Processing Record 46 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=khonuu
# Processing Record 47 of Set 2 | east london
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=mabopane
# Processing Record 48 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=riaba
# Processing Record 49 of Set 2 | east london
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=kirakira
# Processing Record 50 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=los llanos de aridane
# Processing Record 1 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=najran
# Processing Record 2 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=bella vista
# Processing Record 3 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=grand centre
# Processing Record 4 of Set 3 | east london
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=nouakchott
# Processing Record 5 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=cabo san lucas
# Processing Record 6 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=altea
# Processing Record 7 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=hobart
# Processing Record 8 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=lompoc
# Processing Record 9 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=richards bay
# Processing Record 10 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=san pedro de macoris
# Processing Record 11 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=tirlyanskiy
# Processing Record 12 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=hithadhoo
# Processing Record 13 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=ancud
# Processing Record 14 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=provideniya
# Processing Record 15 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=lasa
# Processing Record 16 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=coshocton
# Processing Record 17 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=karpathos
# Processing Record 18 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=tommot
# Processing Record 19 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=kodino
# Processing Record 20 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=amderma
# Processing Record 21 of Set 3 | east london
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=cuajinicuilapa
# Processing Record 22 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=astana
# Processing Record 23 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=mar del plata
# Processing Record 24 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=chodziez
# Processing Record 25 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=roebourne
# Processing Record 26 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=pedro juan caballero
# Processing Record 27 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=porto seguro
# Processing Record 28 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=seoul
# Processing Record 29 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=durban
# Processing Record 30 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=katsuura
# Processing Record 31 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=puerto ayora
# Processing Record 32 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=pombal
# Processing Record 33 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=saint george
# Processing Record 34 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=geraldton
# Processing Record 35 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=villa oliva
# Processing Record 36 of Set 3 | east london
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=roseburg
# Processing Record 37 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=kapaa
# Processing Record 38 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=abadan
# Processing Record 39 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=necochea
# Processing Record 40 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=irpa irpa
# Processing Record 41 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=schweinfurt
# Processing Record 42 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=puerto escondido
# Processing Record 43 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=talnakh
# Processing Record 44 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=uribia
# Processing Record 45 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=magistralnyy
# Processing Record 46 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=sentyabrskiy
# Processing Record 47 of Set 3 | east london
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=lolua
# Processing Record 48 of Set 3 | east london
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=vaini
# Processing Record 49 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=mehamn
# Processing Record 50 of Set 3 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=timra
# Processing Record 1 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=khatanga
# Processing Record 2 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=victoria
# Processing Record 3 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=illoqqortoormiut
# Processing Record 4 of Set 4 | east london
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=college
# Processing Record 5 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=grand gaube
# Processing Record 6 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=fortuna
# Processing Record 7 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=sorland
# Processing Record 8 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=guerrero negro
# Processing Record 9 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=maues
# Processing Record 10 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=arraial do cabo
# Processing Record 11 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=port elizabeth
# Processing Record 12 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=shymkent
# Processing Record 13 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=gravdal
# Processing Record 14 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=cururupu
# Processing Record 15 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=caraballeda
# Processing Record 16 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=pitea
# Processing Record 17 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=avarua
# Processing Record 18 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=mirina
# Processing Record 19 of Set 4 | east london
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=biak
# Processing Record 20 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=nantucket
# Processing Record 21 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=madimba
# Processing Record 22 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=ponta do sol
# Processing Record 23 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=gabrovo
# Processing Record 24 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=lata
# Processing Record 25 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=urubamba
# Processing Record 26 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=georgetown
# Processing Record 27 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=opuwo
# Processing Record 28 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=nioro
# Processing Record 29 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=san patricio
# Processing Record 30 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=ucluelet
# Processing Record 31 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=upernavik
# Processing Record 32 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=vaitape
# Processing Record 33 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=ilulissat
# Processing Record 34 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=nalut
# Processing Record 35 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=thompson
# Processing Record 36 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=merauke
# Processing Record 37 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=qaanaaq
# Processing Record 38 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=esperance
# Processing Record 39 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=dingle
# Processing Record 40 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=sturgeon bay
# Processing Record 41 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=pacific grove
# Processing Record 42 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=cayenne
# Processing Record 43 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=torbay
# Processing Record 44 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=tual
# Processing Record 45 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=diffa
# Processing Record 46 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=coihaique
# Processing Record 47 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=peace river
# Processing Record 48 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=ishikari
# Processing Record 49 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=tasiilaq
# Processing Record 50 of Set 4 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=kruisfontein
# Processing Record 1 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=kloulklubed
# Processing Record 2 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=galesong
# Processing Record 3 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=dallas
# Processing Record 4 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=anadyr
# Processing Record 5 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=lavrentiya
# Processing Record 6 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=caravelas
# Processing Record 7 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=dianopolis
# Processing Record 8 of Set 5 | east london
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=menongue
# Processing Record 9 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=pevek
# Processing Record 10 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=moose factory
# Processing Record 11 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=cherskiy
# Processing Record 12 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=high level
# Processing Record 13 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=hasaki
# Processing Record 14 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=north bend
# Processing Record 15 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=mwanza
# Processing Record 16 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=samalaeulu
# Processing Record 17 of Set 5 | east london
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=codrington
# Processing Record 18 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=saleaula
# Processing Record 19 of Set 5 | east london
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=bulri
# Processing Record 20 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=saldanha
# Processing Record 21 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=ostrovnoy
# Processing Record 22 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=escanaba
# Processing Record 23 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=lebyazhye
# Processing Record 24 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=kiyasovo
# Processing Record 25 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=rio gallegos
# Processing Record 26 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=shirokiy
# Processing Record 27 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=kieta
# Processing Record 28 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=dicabisagan
# Processing Record 29 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=samusu
# Processing Record 30 of Set 5 | east london
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=nikolskoye
# Processing Record 31 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=chokurdakh
# Processing Record 32 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=tiksi
# Processing Record 33 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=saskylakh
# Processing Record 34 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=angra
# Processing Record 35 of Set 5 | east london
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=naryan-mar
# Processing Record 36 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=pinheiro machado
# Processing Record 37 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=asau
# Processing Record 38 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=mayumba
# Processing Record 39 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=bethel
# Processing Record 40 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=hokitika
# Processing Record 41 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=mirnyy
# Processing Record 42 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=souillac
# Processing Record 43 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=ranong
# Processing Record 44 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=cukai
# Processing Record 45 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=clyde river
# Processing Record 46 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=paita
# Processing Record 47 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=phanom thuan
# Processing Record 48 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=haimen
# Processing Record 49 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=japura
# Processing Record 50 of Set 5 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=road town
# Processing Record 1 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=svetlaya
# Processing Record 2 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=jogindarnagar
# Processing Record 3 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=bengkulu
# Processing Record 4 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=shipley
# Processing Record 5 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=okha
# Processing Record 6 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=klaksvik
# Processing Record 7 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=bargal
# Processing Record 8 of Set 6 | east london
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=belmonte
# Processing Record 9 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=port blair
# Processing Record 10 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=formosa
# Processing Record 11 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=cidreira
# Processing Record 12 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=escalerillas
# Processing Record 13 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=martil
# Processing Record 14 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=groningen
# Processing Record 15 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=thinadhoo
# Processing Record 16 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=pemangkat
# Processing Record 17 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=fukue
# Processing Record 18 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=meleuz
# Processing Record 19 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=jiuquan
# Processing Record 20 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=luderitz
# Processing Record 21 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=kuusamo
# Processing Record 22 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=hobyo
# Processing Record 23 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=saint-gaudens
# Processing Record 24 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=san cristobal
# Processing Record 25 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=sao desiderio
# Processing Record 26 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=yerbogachen
# Processing Record 27 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=mabaruma
# Processing Record 28 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=umzimvubu
# Processing Record 29 of Set 6 | east london
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=lagoa
# Processing Record 30 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=moron
# Processing Record 31 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=fereydun kenar
# Processing Record 32 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=tay ninh
# Processing Record 33 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=tadine
# Processing Record 34 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=san lorenzo
# Processing Record 35 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=kununurra
# Processing Record 36 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=marzuq
# Processing Record 37 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=constitucion
# Processing Record 38 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=oum hadjer
# Processing Record 39 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=maceio
# Processing Record 40 of Set 6 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=takoradi
# Processing Record 41 of Set 6 | east london
# ...
# Processing Record 19 of Set 7 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=salalah
# Processing Record 20 of Set 7 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=gimli
# Processing Record 21 of Set 7 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=mrirt
# Processing Record 22 of Set 7 | east london
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=butterworth
# Processing Record 23 of Set 7 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=haflong
# Processing Record 24 of Set 7 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=svetlogorsk
# Processing Record 25 of Set 7 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=xinqing
# Processing Record 26 of Set 7 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=lagdo
# Processing Record 27 of Set 7 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=santa barbara
# Processing Record 28 of Set 7 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=faanui
# Processing Record 29 of Set 7 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=grindavik
# Processing Record 30 of Set 7 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=batagay
# Processing Record 31 of Set 7 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=bukama
# Processing Record 32 of Set 7 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=vila velha
# Processing Record 33 of Set 7 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=kem
# Processing Record 34 of Set 7 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=nola
# Processing Record 35 of Set 7 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=sept-iles
# Processing Record 36 of Set 7 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=alyangula
# Processing Record 37 of Set 7 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=faya
# Processing Record 38 of Set 7 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=puerto del rosario
# Processing Record 39 of Set 7 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=high rock
# Processing Record 40 of Set 7 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=katherine
# Processing Record 41 of Set 7 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=saint anthony
# Processing Record 42 of Set 7 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=boyolangu
# Processing Record 43 of Set 7 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=launceston
# Processing Record 44 of Set 7 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=port macquarie
# Processing Record 45 of Set 7 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=kaohsiung
# Processing Record 46 of Set 7 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=dvinskoy
# Processing Record 47 of Set 7 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=prince rupert
# Processing Record 48 of Set 7 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=mandla
# Processing Record 49 of Set 7 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=aswan
# Processing Record 50 of Set 7 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=maragogi
# Processing Record 1 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=harper
# Processing Record 2 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=vestmanna
# Processing Record 3 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=vasterhaninge
# Processing Record 4 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=morgan city
# Processing Record 5 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=darab
# Processing Record 6 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=jackson
# Processing Record 7 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=ialibu
# Processing Record 8 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=quanzhou
# Processing Record 9 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=semporna
# Processing Record 10 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=tungor
# Processing Record 11 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=miles city
# Processing Record 12 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=mbandaka
# Processing Record 13 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=vila
# Processing Record 14 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=llanes
# Processing Record 15 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=srednekolymsk
# Processing Record 16 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=bedford
# Processing Record 17 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=kamenka
# Processing Record 18 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=karaul
# Processing Record 19 of Set 8 | east london
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=belluno
# Processing Record 20 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=vao
# Processing Record 21 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=nakamura
# Processing Record 22 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=port hedland
# Processing Record 23 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=itarema
# Processing Record 24 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=steinbach
# Processing Record 25 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=henties bay
# Processing Record 26 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=naze
# Processing Record 27 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=ashcroft
# Processing Record 28 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=kosh-agach
# Processing Record 29 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=kobojango
# Processing Record 30 of Set 8 | east london
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=assiniboia
# Processing Record 31 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=yerofey pavlovich
# Processing Record 32 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=bara
# Processing Record 33 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=puro
# Processing Record 34 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=medvezhyegorsk
# Processing Record 35 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=abonnema
# Processing Record 36 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=la ronge
# Processing Record 37 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=punta cardon
# Processing Record 38 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=rantoul
# Processing Record 39 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=kuche
# Processing Record 40 of Set 8 | east london
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=te anau
# Processing Record 41 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=evensk
# Processing Record 42 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=namatanai
# Processing Record 43 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=viedma
# Processing Record 44 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=bandar-e lengeh
# Processing Record 45 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=fayaoue
# Processing Record 46 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=svetlyy
# Processing Record 47 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=mtimbira
# Processing Record 48 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=port-cartier
# Processing Record 49 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=petropavlovka
# Processing Record 50 of Set 8 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=wahran
# Processing Record 1 of Set 9 | east london
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=tapes
# Processing Record 2 of Set 9 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=fort nelson
# Processing Record 3 of Set 9 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=kroya
# Processing Record 4 of Set 9 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=samarinda
# Processing Record 5 of Set 9 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=tapaua
# Processing Record 6 of Set 9 | east london
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=mackenzie
# Processing Record 7 of Set 9 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=jijiga
# Processing Record 8 of Set 9 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=shellbrook
# Processing Record 9 of Set 9 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=bambanglipuro
# Processing Record 10 of Set 9 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=narwar
# Processing Record 11 of Set 9 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=praia
# Processing Record 12 of Set 9 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=turaiyur
# Processing Record 13 of Set 9 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=roma
# Processing Record 14 of Set 9 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=yeppoon
# Processing Record 15 of Set 9 | east london
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=c0518691845369b4b660eb96e42e970f&q=beloha
# Processing Record 16 of Set 9 | east london

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# %%
city_data_df.to_csv("Weather_Database/WeatherPy_Database.csv", index_label="City_ID")
